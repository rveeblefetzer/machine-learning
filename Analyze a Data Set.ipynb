# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
housing = pd.read_csv("boston_housing_data.csv", sep=" ", names= ["NOTHING", "CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MED"])

# %%
del housing["NOTHING"]

# %% [markdown]
# This data set describes Boston neighborhoods, housing and various aspects of living.
#
# Attribute Information:
#
# CRIM: per capita crime rate by town
# ZN: proportion of residential land zoned for lots over 25,000 sq.ft.
# INDUS: proportion of non-retail business acres per town
# CHAS: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# NOX: nitric oxides concentration (parts per 10 million)
# RM: average number of rooms per dwelling
# AGE: proportion of owner-occupied units built prior to 1940
# DIS: weighted distances to five Boston employment centres
# RAD: index of accessibility to radial highways
# TAX: full-value property-tax rate per $10,000
# PTRATIO: pupil-teacher ratio by town
# B: 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# LSTAT: % lower status of the population
# MED: Median value of owner-occupied homes in $1000's

# %%
housing
# Out:
#         CRIM    ZN  INDUS   CHAS    NOX      RM       AGE      DIS    RAD  \
# 0    0.00632  18.0   2.31  0.000  0.538   6.575   65.2000   4.0900    1.0
# 1    0.02731   0.0   7.07  0.000  0.469   6.421   78.9000   4.9671    2.0
# 2    0.02729   0.0   7.07  0.000  0.469   7.185   61.1000   4.9671    2.0
# 3    0.03237   0.0   2.18  0.000  0.458   6.998   45.8000   6.0622    3.0
# 4    0.06905   0.0   2.18  0.000  0.458   7.147   54.2000   6.0622    3.0
# 5    0.02985   0.0   2.18  0.000  0.458   6.430   58.7000   6.0622    3.0
# 6    0.08829  12.5   7.87  0.000  0.524   6.012   66.6000   5.5605    5.0
# 7    0.14455  12.5   7.87  0.000  0.524   6.172   96.1000   5.9505    5.0
# 8    0.21124  12.5   7.87  0.000  0.524   5.631  100.0000   6.0821    5.0
# 9    0.17004  12.5   7.87  0.000  0.524   6.004   85.9000   6.5921    5.0
# 10   0.22489  12.5   7.87  0.000  0.524   6.377   94.3000   6.3467    5.0
# 11   0.11747  12.5   7.87  0.000  0.524   6.009   82.9000   6.2267    5.0
# ...

# %% [markdown]
# Descriptive stats on housing prices in different Boston neighborhoods.

# %%
mean_price = housing["MED"].mean()

# %%
mean_price * 1000
# Out:
# 23750.442477876106

# %%
median_price = housing["MED"].median()

# %%
median_price * 1000
# Out:
# 21950.0

# %%
print (housing[housing.AGE == housing.AGE.min()].MED)
# Out:
# 374   NaN
# Name: MED, dtype: float64

# %%
charles = housing[housing['CHAS'] != 0]

# %%
notcharles = housing[housing['CHAS'] == 0]

# %%
river = plt.scatter(charles['PTRATIO'], charles["CRIM"], color='red')

# %%
notriver = plt.scatter(notcharles['PTRATIO'], notcharles['CRIM'], color='blue')

# %%
plt.legend((river, notriver), ('Near River', 'Not Near River'))

# %%
plt.ylabel("Crime")

# %%
plt.xlabel("Teacher-Pupil Ratio")

# %%
plt.show()

# %% [markdown]
# This graph clearly show high rates of crime in neighborhoods with fewer teachers per student. Also, though, I question the far right end of the teacher-pupil ratio. Four hundred teachers to how many? 400:1?

# %%
plt.clf()

# %%
plt.scatter(housing["B"], housing["DIS"])

# %%
plt.title("Black Residents and Job Centers")

# %%
plt.xlabel("Proportion of Black Residents")

# %%
plt.ylabel("Distance to Job Centers")

# %%
plt.show()

# %% [markdown]
# This graph shows that neighborhoods with a higher proportion of black residents live relatively close to centers of employment. The outlier cluster that lives farther away could be rural, or suburban.

# %%
plt.clf()

# %%
fig, ax = plt.subplots()

# %%
ax2 = ax.twinx()

# %%
nox = housing.plot(ax=ax, kind='scatter', x='MED', y="NOX", color='green')

# %%
RE = housing.plot(ax=ax2, kind="scatter", x="MED", y="INDUS", color="blue", secondary_y=True)

# %%
ax.set_xlabel("Median Home Value")

# %%
ax.set_ylabel('Nitric Oxide Concentration pp 10 million (green)')

# %%
ax2.set_ylabel("Proportion Non-Retail Business (blue)")

# %%
plt.title("NO and Non-Retail Businesses")

# %%
plt.show()

# %% [markdown]
# This graph shows the highest concentration of non-retail businesses also clustered around the highest concentration of nitric oxide. This is also mostly in an area where the median home value is relatively lower. In the Mid-Atlantic cities and states, more people heat their homes with oil, which produces NO. I can imagine that their are more industrial areas of Boston, where home houses are lower but not rock-bottom, and that the homes and possibly industry are emitting a lot of gas.

# %%
plt.clf()

# %%
plt.scatter(housing["RAD"], housing["LSTAT"])

# %%
plt.title("Lower Status Pop. and Highway Accessibility")

# %%
plt.xlabel("Accessibility to Radial Highways")

# %%
plt.ylabel("Percentat of Lower Status of Population")

# %%
plt.show()

# %% [markdown]
# I wanted to see a graph of the percentage of poor people compared with accessiblity to highways. The highway data is defined as "index of accessibility to radial highways"; I assume that the higher the index number means closer proximity to highways. I assume, also, that the population data means a neighborhood population's percentage of lower socieconomic residents. Given that, this graph shows that neighborhoods with more poor people live farther away from highway access. Nearly all of the points are clustered on left side; the outlier on the far right could be poor rural folks who live near an interstate.
